# %%
import os
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
import math

from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler
from common.utils import load_data, mape

# %%
import sys
print(sys.path)
import inspect
import common.utils

module_path = inspect.getfile(common.utils)
print(module_path)
# Out:
# ['c:\\Users\\nbadh\\OneDrive\\Documents\\ML-For-Beginners\\7-TimeSeries\\2-ARIMA\\working', 'c:\\Users\\nbadh\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'c:\\Users\\nbadh\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'c:\\Users\\nbadh\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', '', 'C:\\Users\\nbadh\\AppData\\Roaming\\Python\\Python311\\site-packages', 'C:\\Users\\nbadh\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32', 'C:\\Users\\nbadh\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32\\lib', 'C:\\Users\\nbadh\\AppData\\Roaming\\Python\\Python311\\site-packages\\Pythonwin', 'c:\\Users\\nbadh\\AppData\\Local\\Programs\\Python\\Python311', 'c:\\Users\\nbadh\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages']
# c:\Users\nbadh\OneDrive\Documents\ML-For-Beginners\7-TimeSeries\2-ARIMA\working\common\utils.py

# %%
energy = load_data('../../data')[['load']]
energy.head(5)
# Out:
#                        load
# 2012-01-01 00:00:00  2698.0
# 2012-01-01 01:00:00  2558.0
# 2012-01-01 02:00:00  2444.0
# 2012-01-01 03:00:00  2402.0
# 2012-01-01 04:00:00  2403.0

# %% [markdown]
# ### Plot the data

# %%
energy.plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()
